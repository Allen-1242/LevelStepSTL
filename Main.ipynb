# %%
#Temp testing

# %%
#Ok add the various smoothening methods
#We have both univariate and multivariate methods

# %%
import scipy

from scipy import signal

# %%
import statsmodels as sm

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import HourLocator, DayLocator, DateFormatter
from statsmodels.nonparametric.smoothers_lowess import lowess

# %%
import seaborn as sns

# %%
import numpy as np

# %%
temp = list[2,4,3,2]

# %%
lowess(temp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 lowess(temp)
#
# TypeError: lowess() missing 1 required positional argument: 'exog'

# %%
# Generate data looking like cosine
y = np.random.uniform(0, 4 * np.pi, size=200)
x = np.random.uniform(0, 4 * np.pi, size=200)

# Compute a lowess smoothing of the data
smoothed = sm.nonparametric.lowess(exog=x, endog=y, frac=0.2)

# %%
plt.plot(x)

# %%
import numpy as np
import pylab
import seaborn as sns
import statsmodels.api as sm

sns.set_style("darkgrid")
pylab.rc("figure", figsize=(16, 8))
pylab.rc("font", size=14)

# %%
fig, ax = pylab.subplots()

ax.scatter(x, y)
ax.plot(smoothed[:, 0], smoothed[:, 1], c="k")
pylab.autoscale(enable=True, axis="x", tight=True)

# %%
#Have multiple smoothening functions written in

# %%
from scipy.interpolate import UnivariateSpline
x, y = np.array([1, 2, 3, 4]), np.array([1, np.nan, 3, 4])
w = np.isnan(y)
y[w] = 0.
spl = UnivariateSpline(x, y, w=~w)

# %%
spl

# %%
plt.plot(sp1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 plt.plot(sp1)
#
# NameError: name 'sp1' is not defined

# %%
spl.set_smoothing_factor(0.5)
plt.plot(xs, spl(xs), 'b', lw=3)
plt.show()

# %%
r = sm.tsa.holtwinters.SimpleExpSmoothing(x, initialization_method=None, initial_level=None)

# %%
 fit_SES = r.fit(smoothing_level = 1, optimized=False)

# %%
r.simulate(8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [90], in <cell line: 1>()
# ----> 1 r.simulate(8)
#
# AttributeError: 'SimpleExpSmoothing' object has no attribute 'simulate'

# %%
r.data

# %%
dir(r)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bounds',
#  '_boxcox',
#  '_check_blocked_keywords',
#  '_check_bound_feasibility',
#  '_check_bounds',
#  '_check_kwargs',
#  '_construct_bounds',
#  '_data',
#  '_data_attr',
#  '_enforce_bounds',
#  '_estimate_level',
#  '_estimate_seasonal',
#  '_estimate_trend',
#  '_fit_collinear',
#  '_fit_zeros',
#  '_fixed_parameters',
#  '_formula_max_endog',
#  '_get_exog_names',
#  '_get_index_label_loc',
#  '_get_index_loc',
#  '_get_init_kwds',
#  '_get_prediction_index',
#  '_get_starting_values',
#  '_handle_data',
#  '_index',
#  '_index_dates',
#  '_index_freq',
#  '_index_generated',
#  '_index_inferred_freq',
#  '_index_int64',
#  '_index_none',
#  '_init_dates',
#  '_init_keys',
#  '_initial_level',
#  '_initial_seasonal',
#  '_initial_trend',
#  '_initialization_method',
#  '_initialize',
#  '_initialize_heuristic',
#  '_initialize_known',
#  '_initialize_legacy',
#  '_initialize_simple',
#  '_kwargs_allowed',
#  '_lambda',
#  '_optimize_parameters',
#  '_ordered_names',
#  '_predict',
#  '_set_exog_names',
#  '_setup_brute',
#  '_update_for_fixed',
#  '_use_boxcox',
#  '_y',
#  'damped_trend',
#  'data',
#  'endog',
#  'endog_names',
#  'exog',
#  'exog_names',
#  'fit',
#  'fix_params',
#  'from_formula',
#  'has_seasonal',
#  'has_trend',
#  'hessian',
#  'information',
#  'initial_values',
#  'initialize',
#  'k_constant',
#  'loglike',
#  'nobs',
#  'params',
#  'predict',
#  'score',
#  'seasonal',
#  'seasonal_periods',
#  'trend']
